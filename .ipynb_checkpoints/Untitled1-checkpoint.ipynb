# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

# %%
# Configura o driver do Selenium
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
# Acesse a página
driver.get("https://www.discogs.com/pt_BR/genre/hip+hop")

# %%
# Aguarde o carregamento do conteúdo
driver.implicitly_wait(5)  # Ajuste o tempo de espera conforme necessário

# %%
# Exiba o conteúdo da página
print(driver.page_source)
# Out:
# <html class="is_not_mobile needs_reduced_ui  haslocalstorage no_hastouch no_indevmode no_ismobile hasformdata hashistoryapi hasflexbox" lang="pt-BR" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"><head><script type="text/javascript" async="" src="https://script.4dex.io/a/latest/adagio.js" id="adagiojs-2aed08ecabdb3" data-pid="1240"></script>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <meta http-equiv="content-language" content="pt_BR">
#         <meta http-equiv="pragma" content="no-cache">
#         <meta http-equiv="expires" content="-1">
#
#
#                     <!-- OneTrust Cookies Consent Notice start for discogs.com and GPP Stub-->
# ...

# %%
# Encontre todos os elementos de artistas
artists = driver.find_elements(By.CSS_SELECTOR, 'li.card.card_large')

# %%
# Lista para armazenar os dados dos artistas
artist_data = []

# %%
# Lista de artistas já extraída diretamente (como você forneceu)
artists_only = [
    {"name": "Jay-Z", "link": "https://www.discogs.com/pt_BR/artist/21742-Jay-Z", "image_url": "https://i.discogs.com/GS6Mhb-7_gxvAvtaGpgp_rrOuIuQ3Ob588NWfmVQJaI/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTIxNzQy/LTE1MDUwNjcyNTMt/MTY3OC5qcGVn.jpeg"},
    {"name": "Eminem", "link": "https://www.discogs.com/pt_BR/artist/38661-Eminem", "image_url": "https://i.discogs.com/TScRuENzR0-Fa8cgVuj-kaPfSpa3_hgoVtaomHi3ilI/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTM4NjYx/LTE2NDI5Mjk5NzUt/OTQyOS5qcGVn.jpeg"},
    {"name": "Nas", "link": "https://www.discogs.com/pt_BR/artist/50997-Nas", "image_url": "https://i.discogs.com/BfBtSlpseZPHiS95pWB4KUByqy4hBrDuct3w1VUhGH4/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTUwOTk3/LTE2OTczNjk4MDct/OTcwMi5qcGVn.jpeg"},
    {"name": "2Pac", "link": "https://www.discogs.com/pt_BR/artist/100752-2Pac", "image_url": "https://i.discogs.com/KHRjFbYyydOkIrYmvA472kXD0bpSswoxHQg1vIXmW1Q/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTEwMDc1/Mi0xNDI3MjM1MzUz/LTgzNjQuanBlZw.jpeg"},
    {"name": "Snoop Dogg", "link": "https://www.discogs.com/pt_BR/artist/132084-Snoop-Dogg", "image_url": "https://i.discogs.com/3-q3NuDgZjBZ5cTDFUCExL0S04rm6bOr7-Eyy8LnwX4/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTEzMjA4/NC0xNjYyNTQ4MDEy/LTQ4NjUuanBlZw.jpeg"},
    {"name": "Kanye West", "link": "https://www.discogs.com/pt_BR/artist/137880-Kanye-West", "image_url": "https://i.discogs.com/qzv_6QnQbd-je3-mkJWyh_LaIdla-_FyQtiSsu4LUaQ/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTEzNzg4/MC0xNDkwNTA0ODg0/LTU5NjMuanBlZw.jpeg"},
    {"name": "Lil Wayne", "link": "https://www.discogs.com/pt_BR/artist/1065010-Lil-Wayne", "image_url": "https://i.discogs.com/yIRqkTrlbORcFKZ6wMvLn1MdYwErb26VXwtEAEwKOJ4/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTEwNjUw/MTAtMTUwMDQ4MzE4/MC0xMDYyLnBuZw.jpeg"}
]

# %%
# Acessa o link do primeiro artista
driver.get(artists_only[0]['link'])

# %%
print(artists_only)
# Out:
# [{'name': 'Jay-Z', 'link': 'https://www.discogs.com/pt_BR/artist/21742-Jay-Z', 'image_url': 'https://i.discogs.com/GS6Mhb-7_gxvAvtaGpgp_rrOuIuQ3Ob588NWfmVQJaI/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTIxNzQy/LTE1MDUwNjcyNTMt/MTY3OC5qcGVn.jpeg'}, {'name': 'Eminem', 'link': 'https://www.discogs.com/pt_BR/artist/38661-Eminem', 'image_url': 'https://i.discogs.com/TScRuENzR0-Fa8cgVuj-kaPfSpa3_hgoVtaomHi3ilI/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTM4NjYx/LTE2NDI5Mjk5NzUt/OTQyOS5qcGVn.jpeg'}, {'name': 'Nas', 'link': 'https://www.discogs.com/pt_BR/artist/50997-Nas', 'image_url': 'https://i.discogs.com/BfBtSlpseZPHiS95pWB4KUByqy4hBrDuct3w1VUhGH4/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9BLTUwOTk3/LTE2OTczNjk4MDct/OTcwMi5qcGVn.jpeg'}, {'name': '2Pac', 'link': 'https://www.discogs.com/pt_BR/artist/100752-2Pac', 'image_url': 'https://i.discogs.com/KHRjFbYyydOkIrYmvA472kXD0bpSswoxHQg1vIXmW1Q/rs:fill/g:s
# ...

# %%
album = driver.find_element(By.CLASS_NAME, 'facets_1zLcg').text

# %%
print(album)
# Out:
# Albums
# 29

# %%
# Encontre todos os elementos dos albuns
Albuns = driver.find_elements(By.CSS_SELECTOR, 'discographyGrid_31ecR')

# %%
# Lista para armazenar os dados dos artistas
Albuns_data = []

# %%
git remote set-url master https://github.com/lohlaiandra/Neoway.git
